# %% [markdown]
# # Stack Overflow Annual Developer Survey 2019
#
# With nearly 90,000 responses fielded from over 170 countries and dependent territories, our 2019 Annual Developer Survey examines all aspects of the developer experience from career satisfaction and job search to education and opinions on open source software.

# %%
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/dsxuser/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# ...

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#        Column                                       QuestionText
# 0  Respondent  Randomized respondent ID number (not in order ...
# 1       Hobby                            Do you code as a hobby?
# 2  OpenSource         Do you contribute to open source projects?
# 3     Country          In which country do you currently reside?
# 4     Student  Are you currently enrolled in a formal, degree...

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# Questions:
#
# Meaning of fulltime employees of the top 3 countries represented in the survey.
#
# - Which language do the participants plan to work with in 2020?
# - Which database do the participants plan to work with in 2020?
# - Which plattform do the participants plan to work with in 2020?
# - What are their career prospects for the next 5 years?
#
#
#
# - Which technologies are used and will be used 2020
# - Which databases are used and will be used 2020
# - Which education will help for a higher salary in each country as a full time employee
# - Which role will help for a higher salary in each country as a full time employee

# %%
def get_description(column_name, schema=df_schema):
    '''
    INPUT - schema - pandas dataframe with the schema of the developers survey
            column_name - string - the name of the column you would like to know about
    OUTPUT - 
            desc - string - the description of the column
    '''
    desc = list(schema[schema['Column'] == column_name]['QuestionText'])[0]
    return desc

# %%
get_description('Employment')
# Out:
# 'Which of the following best describes your current employment status?'

# %%
get_description('ConvertedSalary')
# Out:
# 'Salary converted to annual USD salaries using the exchange rate on 2018-01-18, assuming 12 working months and 50 working weeks.'

# %%
get_description('DatabaseWorkedWith')
# Out:
# 'Which of the following database environments have you done extensive development work in over the past year, and which do you want to work in over the next year?   (If you both worked with the database and want to continue to do so, please check both boxes in that row.)'

# %%
get_description('DatabaseDesireNextYear')
# Out:
# 'Which of the following database environments have you done extensive development work in over the past year, and which do you want to work in over the next year?   (If you both worked with the database and want to continue to do so, please check both boxes in that row.)'

# %%
get_description('LanguageDesireNextYear')
# Out:
# 'Which of the following programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year?  (If you both worked with the language and want to continue to do so, please check both boxes in that row.)'

# %%
get_description('Country')
# Out:
# 'In which country do you currently reside?'

# %% [markdown]
# ## Data Understanding

# %%
df.shape
# Out:
# (98855, 129)

# %%
df.describe()
# Out:
#           Respondent    AssessJob1    AssessJob2    AssessJob3    AssessJob4  \
# count   98855.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean    50822.971635      6.397089      6.673524      5.906875      4.065791
# std     29321.650410      2.788428      2.531202      2.642734      2.541196
# min         1.000000      1.000000      1.000000      1.000000      1.000000
# 25%     25443.500000      4.000000      5.000000      4.000000      2.000000
# 50%     50823.000000      7.000000      7.000000      6.000000      4.000000
# 75%     76219.500000      9.000000      9.000000      8.000000      6.000000
# max    101592.000000     10.000000     10.000000     10.000000     10.000000
#
#          AssessJob5    AssessJob6    AssessJob7    AssessJob8    AssessJob9  \
# count  66985.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean       3.953243      4.407196      5.673181      4.225200      7.640009
# ...

# %%
df.isnull().sum()
# Out:
# Respondent                         0
# Hobby                              0
# OpenSource                         0
# Country                          412
# Student                         3954
# Employment                      3534
# FormalEducation                 4152
# UndergradMajor                 19819
# CompanySize                    27324
# DevType                         6757
# YearsCoding                     5020
# YearsCodingProf                20952
# JobSatisfaction                29579
# CareerSatisfaction             22351
# HopeFiveYears                  23137
# JobSearchStatus                19367
# LastNewJob                     19966
# AssessJob1                     31870
# AssessJob2                     31870
# AssessJob3                     31870
# AssessJob4                     31870
# AssessJob5                     31870
# AssessJob6                     31870
# AssessJob7                     31870
# AssessJob8                     31870
# ...

# %%
status_vals = df['Employment'].value_counts()

(status_vals/df.shape[0]).plot(kind='bar')
plt.title(get_description('Employment'))
# Out:
# Text(0.5, 1.0, 'Which of the following best describes your current employment status?')

# %%
df['Employment'].value_counts()
# Out:
# Employed full-time                                      70495
# Independent contractor, freelancer, or self-employed     9282
# Not employed, but looking for work                       5805
# Employed part-time                                       5380
# Not employed, and not looking for work                   4132
# Retired                                                   227
# Name: Employment, dtype: int64

# %%
df['DatabaseDesireNextYear'].value_counts()
# Out:
# MySQL                                                                                                                                                                                                                         2889
# PostgreSQL                                                                                                                                                                                                                    2564
# SQL Server                                                                                                                                                                                                                    2413
# MongoDB                                                                                                                                                                                                                       2091
# ...

# %%
df['Exercise'].value_counts()
# Out:
# I don't typically exercise    26995
# 1 - 2 times per week          20932
# 3 - 4 times per week          14318
# Daily or almost every day      9863
# Name: Exercise, dtype: int64

# %%
df['WakeTime'].value_counts()
# Out:
# Between 7:01 - 8:00 AM          21250
# Between 6:01 - 7:00 AM          20322
# Between 8:01 - 9:00 AM          10592
# Between 5:00 - 6:00 AM           8922
# I do not have a set schedule     3842
# Between 9:01 - 10:00 AM          3453
# Before 5:00 AM                   1730
# Between 10:01 - 11:00 AM         1020
# Between 11:01 AM - 12:00 PM       387
# I work night shifts               327
# After 12:01 PM                    301
# Name: WakeTime, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male                                                                         59458
# Female                                                                        4025
# Non-binary, genderqueer, or gender non-conforming                              284
# Female;Transgender                                                             145
# Male;Non-binary, genderqueer, or gender non-conforming                         128
# Transgender                                                                    105
# Female;Male                                                                     98
# Transgender;Non-binary, genderqueer, or gender non-conforming                   51
# Female;Male;Transgender;Non-binary, genderqueer, or gender non-conforming       50
# Female;Non-binary, genderqueer, or gender non-conforming                        50
# Male;Transgender                                                                29
# ...

# %%
df['Country'].value_counts()
# Out:
# United States                            20309
# India                                    13721
# Germany                                   6459
# United Kingdom                            6221
# Canada                                    3393
# Russian Federation                        2869
# France                                    2572
# Brazil                                    2505
# Poland                                    2122
# Australia                                 2018
# Netherlands                               1841
# Spain                                     1769
# Italy                                     1535
# Ukraine                                   1279
# Sweden                                    1164
# Pakistan                                  1050
# China                                     1037
# Switzerland                               1010
# Turkey                                    1004
# Israel                                    1003
# ...

# %%
df['FormalEducation'].value_counts()
# Out:
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              43659
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           21396
# Some college/university study without earning a degree                                11710
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     8951
# Associate degree                                                                       2970
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              2214
# Primary/elementary school                                                              1656
# Professional degree (JD, MD, etc.)                                                     1447
# I never completed any formal education                                                  700
# Name: FormalEducation, dtype: int64

# %%
df['FormalEducation'].isnull().value_counts()
# Out:
# False    94703
# True      4152
# Name: FormalEducation, dtype: int64

# %%
df.groupby('FormalEducation')['ConvertedSalary'].mean()
# Out:
# FormalEducation
# Associate degree                                                                       99178.012558
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                               96462.508500
# I never completed any formal education                                                151409.604520
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           100588.150282
# Other doctoral degree (Ph.D, Ed.D., etc.)                                             127154.871537
# Primary/elementary school                                                              71942.713918
# Professional degree (JD, MD, etc.)                                                     81716.982026
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     69065.995366
# Some college/university study without earning a degree                                 92913.785188
# Name: ConvertedSalary, dtype: float64

# %%
df.groupby('Age')['IDE'].value_counts()
# Out:
# Age                 IDE
# 18 - 24 years old   Visual Studio Code                                                     402
#                     Vim                                                                    356
#                     Sublime Text                                                           348
#                     Visual Studio;Visual Studio Code                                       342
#                     Notepad++;Visual Studio;Visual Studio Code                             297
#                     Notepad++;Visual Studio                                                276
#                     Visual Studio                                                          238
#                     Atom                                                                   211
#                     Sublime Text;Vim                                                       148
#                     Vim;Visual Studio Code                                                 137
# ...

# %%
df.groupby('Age')['ConvertedSalary'].mean()
# Out:
# Age
# 18 - 24 years old      57583.397661
# 25 - 34 years old      92099.256363
# 35 - 44 years old     128139.720047
# 45 - 54 years old     153433.451049
# 55 - 64 years old     191835.557823
# 65 years or older     121492.553846
# Under 18 years old     35843.769863
# Name: ConvertedSalary, dtype: float64

# %%
df.groupby('IDE')['ConvertedSalary'].mean()
# Out:
# IDE
# Android Studio                                                                                                                                                                                                      49471.517588
# Android Studio;Atom                                                                                                                                                                                                111043.224138
# Android Studio;Atom;Coda                                                                                                                                                                                            29376.000000
# Android Studio;Atom;Coda;Eclipse                                                                                                                                                                                    19392.000000
# ...

# %% [markdown]
# ## Data Preperation

# %%
df_emp = df[df['Employment'] == 'Employed full-time']

# %%
df_emp['DatabaseDesireNextYear'].value_counts()
# Out:
# SQL Server                                                                                                                                                                             1976
# PostgreSQL                                                                                                                                                                             1878
# MySQL                                                                                                                                                                                  1708
# MongoDB                                                                                                                                                                                1525
# SQL Server;Microsoft Azure (Tables, CosmosDB, SQL, etc)                                                                                                                                 775
# ...

# %%
possible_vals = []
for dbs in df_emp['DatabaseDesireNextYear']:
    for db in str(dbs).split(';'):
        possible_vals.append(db)

# %%
possible_vals = set(possible_vals)
possible_vals
# Out:
# {'Amazon DynamoDB',
#  'Amazon RDS/Aurora',
#  'Amazon Redshift',
#  'Apache HBase',
#  'Apache Hive',
#  'Cassandra',
#  'Elasticsearch',
#  'Google BigQuery',
#  'Google Cloud Storage',
#  'IBM Db2',
#  'MariaDB',
#  'Memcached',
#  'Microsoft Azure (Tables, CosmosDB, SQL, etc)',
#  'MongoDB',
#  'MySQL',
#  'Neo4j',
#  'Oracle',
#  'PostgreSQL',
#  'Redis',
#  'SQL Server',
#  'SQLite',
#  'nan'}

# %%
from collections import defaultdict
def total_count(df, col1, col2, look_for):
    '''
    INPUT:
    df - the pandas dataframe you want to search
    col1 - the column name you want to look through
    col2 - the column you want to count values from
    look_for - a list of strings you want to search for in each row of df[col]

    OUTPUT:
    new_df - a dataframe of each look_for with the count of how often it shows up
    '''
    new_df = defaultdict(int)
    #loop through list of ed types
    for val in look_for:
        #loop through rows
        for idx in range(df.shape[0]):
            #if the ed type is in the row add 1
            if val in df[col1][idx]:
                new_df[val] += int(df[col2][idx])
    new_df = pd.DataFrame(pd.Series(new_df)).reset_index()
    new_df.columns = [col1, col2]
    new_df.sort_values('count', ascending=False, inplace=True)
    return new_df

# %%
def clean_and_plot(df, column, title='Plot', plot=True):
    '''
    INPUT 
        df - a dataframe holding the CousinEducation column
        title - string the title of your plot
        axis - axis object
        plot - bool providing whether or not you want a plot back
        
    OUTPUT
        study_df - a dataframe with the count of how many individuals
        Displays a plot of pretty things related to the CousinEducation column.
    '''
    possible_vals = []
    for dbs in df[column]:
        for db in str(dbs).split(';'):
            possible_vals.append(db)
    
    possible_vals = set(possible_vals)
    
    study = df[column].value_counts().reset_index()
    study.rename(columns={'index': 'method', column: 'count'}, inplace=True)
    study_df = total_count(study, 'method', 'count', possible_vals)

    study_df.set_index('method', inplace=True)
    if plot:
        (study_df/study_df.sum()).plot(kind='bar', legend=None);
        plt.title(title);
        plt.show()
    props_study_df = study_df/study_df.sum()
    return props_study_df

# %%
props_df = clean_and_plot(df_emp, 'Age')

# %%
temp_df = clean_and_plot(df_emp, 'DatabaseDesireNextYear', title='Database desired 2020 form German full-time worker')

# %%
props_df = clean_and_plot(df_emp, 'PlatformWorkedWith')

# %%
props_df = clean_and_plot(df_emp, 'PlatformDesireNextYear')

# %%
props_df = clean_and_plot(df_emp, 'FrameworkDesireNextYear')

# %%
props_df = clean_and_plot(df_emp, 'IDE')

# %%
df_emp[df_emp['Country'] == 'Germany'].groupby('Country')['Country'].count()
# Out:
# Country
# Germany    4383
# Name: Country, dtype: int64

# %%
df_emp_de = df_emp[df_emp['Country'] == 'Germany']

# %%
df_emp_de.shape
# Out:
# (4383, 129)

# %%
df_de_n = clean_and_plot(df_emp_de, 'DatabaseDesireNextYear', plot=False)
df_de_t = clean_and_plot(df_emp_de, 'DatabaseWorkedWith', plot=False)

df_both = df_de_t.join(df_de_n, lsuffix='_2019', rsuffix='_2020', on='method')
df_both.plot(kind="bar", figsize=(16, 8) )

# %%
df_de_n = clean_and_plot(df_emp_de, 'LanguageDesireNextYear', plot=False)
df_de_t = clean_and_plot(df_emp_de, 'LanguageWorkedWith', plot=False)

df_both = df_de_t.join(df_de_n, lsuffix='_2019', rsuffix='_2020', on='method')
df_both.plot(kind="bar", figsize=(16, 8) )

# %%
df_de_n = clean_and_plot(df_emp_de, 'PlatformDesireNextYear', plot=False)
df_de_t = clean_and_plot(df_emp_de, 'PlatformWorkedWith', plot=False)

df_both = df_de_t.join(df_de_n, lsuffix='_2019', rsuffix='_2020', on='method')
df_both.plot(kind="bar", figsize=(16, 8) )

# %%
df_de = clean_and_plot(df_emp_de, 'HopeFiveYears', plot=False)

df_de.plot(kind="barh", figsize=(8, 8) )

# %%
df_de = clean_and_plot(df[df['Country'] == 'Germany'], 'IDE', plot=False)
df_us = clean_and_plot(df[df['Country'] == 'United States'], 'IDE', plot=False)

df_both = df_de.join(df_us, lsuffix='_de', rsuffix='_us', on='method')
df_both.plot.bar()

# %%
df_emp_us = df_emp[df_emp['Country'] == 'United States']
df_emp_in = df_emp[df_emp['Country'] == 'India']

# %%
df_emp_us.shape
# Out:
# (16031, 129)

# %%
df_emp_in.shape
# Out:
# (10252, 129)

# %%
df_de = clean_and_plot(df_emp_de, 'DatabaseDesireNextYear', plot=False)
df_us = clean_and_plot(df_emp_us, 'DatabaseDesireNextYear', plot=False)
df_in = clean_and_plot(df_emp_in, 'DatabaseDesireNextYear', plot=False)

df_both = df_us.join(df_de, lsuffix='_us', rsuffix='_de', on='method')
df_all = df_both.join(df_in, rsuffix='_in', on='method')
df_all.plot(kind="bar", figsize=(12, 8) )

# %%
df_de = clean_and_plot(df_emp_de, 'HopeFiveYears', plot=False)
df_us = clean_and_plot(df_emp_us, 'HopeFiveYears', plot=False)

df_both = df_de.join(df_us, lsuffix='_de', rsuffix='_us', on='method')
df_both.plot.barh()

# %%
df_de = clean_and_plot(df_emp_de, 'LanguageDesireNextYear', plot=False)
df_us = clean_and_plot(df_emp_us, 'LanguageDesireNextYear', plot=False)
df_in = clean_and_plot(df_emp_in, 'LanguageDesireNextYear', plot=False)

df_both = df_us.join(df_de, lsuffix='_us', rsuffix='_de', on='method')
df_all = df_both.join(df_in, rsuffix='_in', on='method')
df_all.plot(kind="bar", figsize=(16, 8) )

# %%
df_de = clean_and_plot(df_emp_de, 'DevType', plot=False)
df_us = clean_and_plot(df_emp_us, 'DevType', plot=False)
df_in = clean_and_plot(df_emp_in, 'DevType', plot=False)

df_both = df_us.join(df_de, lsuffix='_us', rsuffix='_de', on='method')
df_all = df_both.join(df_in, rsuffix='_in', on='method')
df_all.plot(kind="bar", figsize=(12, 8) )

# %%
df_de = clean_and_plot(df[df['Country'] == 'Germany'], 'PlatformDesireNextYear', plot=False)
df_us = clean_and_plot(df[df['Country'] == 'United States'], 'PlatformDesireNextYear', plot=False)
df_in = clean_and_plot(df[df['Country'] == 'India'], 'PlatformDesireNextYear', plot=False)

df_both = df_us.join(df_de, lsuffix='_us', rsuffix='_de', on='method')
df_all = df_both.join(df_in, rsuffix='_in', on='method')
df_all.plot(kind="bar", figsize=(12, 8) )

# %% [markdown]
# ## Modelling

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ## Deployment
